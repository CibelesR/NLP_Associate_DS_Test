# %% [markdown]
# # Language Detection

# %%
#!pip install spacy_cld

# %%
#imports
import spacy
from spacy_cld import LanguageDetector

import sys, glob

# %%
nlp = spacy.load('en')

# %%
language_detector = LanguageDetector()
nlp.add_pipe(language_detector)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-41efccc26ff9> in <module>
# ----> 1 language_detector = LanguageDetector()
#       2 nlp.add_pipe(language_detector)
#
# ~/miniconda3/envs/ea_env/lib/python3.7/site-packages/spacy_cld/spacy_cld.py in __init__(self, attrs)
#      28     def __init__(self, attrs=('languages', 'language_scores')):
#      29         self._languages, self._scores = attrs
# ---> 30         Doc.set_extension(self._languages, getter=get_languages)
#      31         Doc.set_extension(self._scores, getter=get_scores)
#      32         Span.set_extension(self._languages, getter=get_languages)
#
# doc.pyx in spacy.tokens.doc.Doc.set_extension()
#
# ValueError: [E090] Extension 'languages' already exists on Doc. To overwrite the existing extension, set `force=True` on `Doc.set_extension`.

# %%
def what_language(doc):
    doc1 = nlp(doc)
    b = doc1._.languages
    a = ''.join(doc1._.languages)
    print(a)
    #b = doc1._.language_scores[a]
    print(b)
    #print(f'Text is in: {a}\nPercent of language: {doc1._.language_scores[a]*100}%')
    #return(a)

# %%
doc = '/Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr/apr-book-1013-fr.txt'
what_language(doc)
# Out:
# en
# ['en']

# %%
path = '/Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr'
for f in glob.glob(path + '/*.txt'):
    print(f)
    doc = open(f, encoding='utf-8').read()
    what_language(doc)
# Out:
# /Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr/apr-book-1003-fr.txt
# fr
# ['fr']
# /Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr/apr-book-1004-fr.txt
# fr
# ['fr']
# /Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr/apr-book-1008-fr.txt
# fr
# ['fr']
# /Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr/apr-book-1009-fr.txt
# fr
# ['fr']
# /Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr/apr-book-1014-fr.txt
# fr
# ['fr']
# /Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr/apr-book-1018-fr.txt
# fr
# ['fr']
# /Users/Natalio/Desktop/nlp_associate_ds_test/NLP_Associate_DS_Test/data/documents_challenge/APR/fr/apr-book-1019-fr.txt
# fr
# ['fr']
# ...

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined
